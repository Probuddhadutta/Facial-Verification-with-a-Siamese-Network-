# %%
# !pip install tensorflow

# %%
# !pip install tensorflow-gpu
# Out:
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
 # !pip install opencv-python matplotlib

# %%
# Import standard dependencies
import cv2
import os
import random
import numpy as np
from matplotlib import pyplot as plt

# %%
# Import tensorflow dependencies - Functional API
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Layer, Conv2D, Dense, MaxPooling2D, Input, Flatten
import tensorflow as tf

# %%
# Avoid OOM errors by setting GPU Memory Consumption Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
# Setup paths
POS_PATH = os.path.join('data', 'positive')
NEG_PATH = os.path.join('data', 'negative')
ANC_PATH = os.path.join('data', 'anchor')

# %%
# Make the directories
os.makedirs(POS_PATH)
os.makedirs(NEG_PATH)
os.makedirs(ANC_PATH)

# %%
# http://vis-www.cs.umass.edu/lfw/

# %%
# Uncompress Tar GZ Labelled Faces in the Wild Dataset
# !tar -xf lfw.tgz
# Out:
# tar: lfw.tgz: Cannot open: No such file or directory
# tar: Error is not recoverable: exiting now

# %%
# Move LFW Images to the following repository data/negative
for directory in os.listdir('lfw'):
    for file in os.listdir(os.path.join('lfw', directory)):
        EX_PATH = os.path.join('lfw', directory, file)
        NEW_PATH = os.path.join(NEG_PATH, file)
        os.replace(EX_PATH, NEW_PATH)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-b7ea30580a6b> in <cell line: 2>()
#       1 # Move LFW Images to the following repository data/negative
# ----> 2 for directory in os.listdir('lfw'):
#       3     for file in os.listdir(os.path.join('lfw', directory)):
#       4         EX_PATH = os.path.join('lfw', directory, file)
#       5         NEW_PATH = os.path.join(NEG_PATH, file)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'lfw'

# %%
import os
   print(os.listdir())
# Out:
#   File "<ipython-input-23-4aa7722a6372>", line 2
#     print(os.listdir())
#     ^
# IndentationError: unexpected indent

# %%
# !tar -xf lfw.tgz
# Out:
# tar: lfw.tgz: Cannot open: No such file or directory
# tar: Error is not recoverable: exiting now

# %%
# Import uuid library to generate unique image names
import uuid

# %%
os.path.join(ANC_PATH, '{}.jpg'.format(uuid.uuid1()))
# Out:
# 'data/anchor/fe58641a-c915-11ef-b7cf-0242ac1c000c.jpg'

# %%
# Establish a connection to the webcam
cap = cv2.VideoCapture(4)
while cap.isOpened():
    ret, frame = cap.read()

    # Cut down frame to 250x250px
    frame = frame[120:120+250,200:200+250, :]

    # Collect anchors
    if cv2.waitKey(1) & 0XFF == ord('a'):
        # Create the unique file path
        imgname = os.path.join(ANC_PATH, '{}.jpg'.format(uuid.uuid1()))
        # Write out anchor image
        cv2.imwrite(imgname, frame)

    # Collect positives
    if cv2.waitKey(1) & 0XFF == ord('p'):
        # Create the unique file path
        imgname = os.path.join(POS_PATH, '{}.jpg'.format(uuid.uuid1()))
        # Write out positive image
        cv2.imwrite(imgname, frame)

    # Show image back to screen
    cv2.imshow('Image Collection', frame)

    # Breaking gracefully
    if cv2.waitKey(1) & 0XFF == ord('q'):
        break

# Release the webcam
cap.release()
# Close the image show frame
cv2.destroyAllWindows()

# %%
plt.imshow(frame[120:120+250,200:200+250, :])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-4811ca8852a9> in <cell line: 1>()
# ----> 1 plt.imshow(frame[120:120+250,200:200+250, :])
#
# NameError: name 'frame' is not defined

# %%
# Display the last frame using plt.imshow after the loop
plt.imshow(cap.read()[1][120:120+250,200:200+250, :]); plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-ce03b6c0c36b> in <cell line: 2>()
#       1 # Display the last frame using plt.imshow after the loop
# ----> 2 plt.imshow(cap.read()[1][120:120+250,200:200+250, :]); plt.show()
#
# TypeError: 'NoneType' object is not subscriptable

# %%
v
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-2912596a4014> in <cell line: 1>()
# ----> 1 v
#
# NameError: name 'v' is not defined

# %%
def preprocess_twin(input_img, validation_img, label):
    return(preprocess(input_img), preprocess(validation_img), label)

# %%
res = preprocess_twin(*exampple)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-5598883d16aa> in <cell line: 1>()
# ----> 1 res = preprocess_twin(*exampple)
#
# NameError: name 'exampple' is not defined

# %%
# Assuming 'example' was intended and contains the required data
example = (image1, image2, label) # Replace image1, image2, label with actual values

res = preprocess_twin(*example)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-81b0128d90a2> in <cell line: 2>()
#       1 # Assuming 'example' was intended and contains the required data
# ----> 2 example = (image1, image2, label) # Replace image1, image2, label with actual values
#       3
#       4 res = preprocess_twin(*example)
#
# NameError: name 'image1' is not defined
